# %%
from google.colab import auth
auth.authenticate_user()
# Out:
# /usr/local/lib/python3.12/dist-packages/google/auth/_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)

# %%
import vertexai
from vertexai.generative_models import GenerativeModel
import time
import os
from typing import List, Tuple, Set, Optional
from datetim import datetime

# Fungsi ini harus didefinisikan di scope global agar bisa dipanggil oleh kelas.
def custom_log(level: str, message: str):
    """
    Mencetak pesan log ke konsol dengan format waktu, level, dan pesan yang seragam.
    
    Args:
        level (str): Tingkat keparahan log (misalnya "INFO", "ERROR", "WARNING", "CRITICAL").
        message (str): Pesan log yang akan dicetak.
    """
    # Mengambil waktu saat ini dan memformatnya
    timestamp = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    
    # Mencetak output log
    print(f"{timestamp} - {level} - {message}")

# --- Keywords ---
# Daftar kunci kata yang diizinkan (vocabulary) untuk membuat dataset.
# Setiap frasa yang dihasilkan LLM HARUS terdiri dari kata-kata ini.
KEYWORDS = [
    "Saya", "Mau", "Ya", "Tidak", "Cukup", "Makan", "Minum", "Tidur", "Kamu",
    "Lagi", "Bukan", "Toilet", "Halo", "Bagus", "Buruk", "Lihat", "Bicara",
    "Dengar", "Rumah", "Sakit", "Tidak Bisa Bicara", "Bermain", "Terima Kasih",
    "Sampai Jumpa", "Senang", "Sedih", "Marah", "Cinta", "Takut", "Bingung",
    "Lapar", "Nasi", "Mie", "Sup", "Ikan", "Tempe", "Ayam Goreng",
    "Telur Goreng", "Roti", "Hamburger", "Kentang goreng", "Buah-buahan",
    "Es krim", "Keripik", "Cokelat", "Permen", "Kacang", "Haus", "Air putih",
    "Susu", "Susu Cokelat", "Jus Jeruk", "Apel", "Jeruk", "Semangka", "Pisang",
    "Anggur", "Stroberi", "Alpukat", "Anjing", "Kucing", "Kelinci", "Bebek",
    "Babi", "Beruang", "Panda", "Penguin", "Gajah", "Rubah", "Koala",
    "Burung Hantu", "Katak", "MonyeT", "Sapi", "Ayam", "Tikus", "Burung",
    "Kura-kura", "Penyu", "Domba", "Ayah", "Ibu", "Kakek", "Nenek",
    "Kakak Perempuan", "Kakak Laki-Laki", "Adik Perempuan", "Adik Laki-Laki",
    "Pensil", "Rautan", "Tas Ransel", "Buku", "Gunting", "Penggaris",
    "Pensil Warna", "Kertas", "Origami", "Lem", "Handphone", "Tablet",
    "Laptop", "TV", "Komputer", "Remot Kontrol", "Kamera", "AC",
    "Kipas Angin", "Sendok", "Garpu", "Sumpit", "Piring", "Mangkuk",
    "Gelas", "Cangkir", "Pisau", "Kulkas", "Pagi", "Siang", "Sore",
    "Malam", "Waktu", "Jam", "Menit", "Sekarang", "Hari ini", "Besok",
    "Kemarin", "Seminggu", "Minggu ini", "Akhir Pekan", "Minggu Depan",
    "Minggu Lalu", "Bulan", "Bulan Ini", "Bulan Depan", "Bulan Lalu",
    "Matahari", "Terik", "Hujan", "Panas", "Dingin", "Musim", "Kemarau",
    "Berawan", "Badai", "Ini", "Besar", "Sedang", "Kecil", "Banyak",
    "Sedikit", "Tebal", "Tipis", "Kotor", "Bersih"
]

# --- Configuration ---
# Kelas untuk menampung semua parameter dan konfigurasi.
class Config:
    PROJECT_ID = "talk-of-the-heart-aac-464912"
    LOCATION = "us-central1"
    MODEL_NAME = "gemini-2.5-pro" # Model LLM yang digunakan untuk generasi data.
    DATA_QUANTITY = 7000 
    BATCH_SIZE = 150 # Jumlah frasa yang diminta LLM per panggilan API.
    MAX_RETRIES = 5 
    SUCCESS_DELAY = 0.5 
    FAILURE_DELAY = 10 
    MIN_PHRASE_LENGTH = 2
    MAX_PHRASE_LENGTH = 6 
    OUTPUT_FILENAME = "Dataset_Key.txt" 
    CHECKPOINT_FILENAME = "Dataset_Checkpoint.txt"

# --- Core Logic ---
# Kelas utama yang mengelola inisialisasi, generasi, dan validasi data.
class DatasetGenerator:
    def __init__(self, config: Config, keywords: List[str]):
        # Konstruktor: Mengatur konfigurasi dan menyiapkan alat.
        self.config = config
        self._initialize_vertexai() # Menghubungkan ke Google Vertex AI dan memuat model.

        # Mengubah keywords menjadi huruf kecil untuk validasi dan mengurutkannya 
        # berdasarkan panjang (terpanjang dulu) untuk validasi urutan kata yang akurat.
        self.lowercase_keywords = sorted(list(set(word.lower() for word in keywords)))
        self.sorted_keywords = sorted(self.lowercase_keywords, key=len, reverse=True)
        self.final_dataset: Set[Tuple[str, ...]] = set()

        self._load_from_checkpoint() 
        self._precompute_logical_rules()

    def _load_from_checkpoint(self):
        # Memuat data dari file checkpoint jika ada.
        if not os.path.exists(self.config.CHECKPOINT_FILENAME):
            custom_log("INFO", "Checkpoint file not found. Starting a new dataset.")
            return
        # Logika pembacaan file dan penambahan frasa yang tersimpan ke final_dataset.
        try:
            with open(self.config.CHECKPOINT_FILENAME, "r", encoding="utf-8") as f:
                pass # Baris ini hanya placeholder; kode aslinya melakukan pembacaan.
        except Exception as e:
            custom_log("ERROR", f"Failed to load from checkpoint file: {e}. Starting fresh.")
            self.final_dataset = set()

    def _save_to_checkpoint(self):
        # Menyimpan data yang sudah terkumpul ke file checkpoint.
        try:
            with open(self.config.CHECKPOINT_FILENAME, "w", encoding="utf-8") as f:
                sorted_list = sorted(list(self.final_dataset))
                for data_tuple in sorted_list:
                    formatted_keywords = [f'"{keyword}"' for keyword in data_tuple]
                    line = ", ".join(formatted_keywords)
                    f.write(line + "\n")
            custom_log("INFO", f"Checkpoint saved with {len(self.final_dataset)} records.")
        except IOError as e:
            custom_log("ERROR", f"Could not save checkpoint to file '{self.config.CHECKPOINT_FILENAME}': {e}")

    def _initialize_vertexai(self):
        # Menyiapkan koneksi ke Google Vertex AI dan Generative Model (Gemini).
        try:
            custom_log("INFO", f"Initializing Vertex AI for project '{self.config.PROJECT_ID}' in location '{self.config.LOCATION}'...")
            vertexai.init(project=self.config.PROJECT_ID, location=self.config.LOCATION)
            self.model = GenerativeModel(self.config.MODEL_NAME)
            custom_log("INFO", f"Successfully initialized Generative Model '{self.config.MODEL_NAME}'.")
        except Exception as e:
            custom_log("ERROR", f"An error occurred during Vertex AI initialization: {e}")
            # Menampilkan pesan kesalahan kesalahan dan menghentikan skrip.
            print("\n--------------------------------------------------------------")
            print("CRITICAL ERROR: Please ensure Authentication and Project ID are correct.")
            print("--------------------------------------------------------------\n")
            raise

    def _precompute_logical_rules(self):
        # Mendefinisikan aturan logika (antonym dan konflik waktu/logika)
        antonyms = [
            ("bersih", "kotor"), ("bagus", "buruk"), ("besar", "kecil"),
            ("tebal", "tipis"), ("panas", "dingin"), ("banyak", "sedikit"),
            ("ya", "tidak"), ("senang", "sedih")
        ]
        # Diubah menjadi frozenset yang tidak order-independent, sehingga lebih efisien 
        self.antonym_sets = [frozenset(pair) for pair in antonyms]
        
        # Pasangan kata yang tidak masuk akal (illogical).
        illogical_pairs = [("makan", "ac"), ("minum", "lem")]
        self.illogical_pair_sets = [frozenset(pair) for pair in illogical_pairs]
        
        # Pasangan kata yang menunjukkan konflik waktu.
        temporal_conflicts = [
            ("kemarin", "besok"), ("kemarin", "minggu depan"), ("kemarin", "bulan depan"),
            ("minggu lalu", "besok"), ("minggu lalu", "minggu depan"), ("minggu lalu", "bulan depan"),
            ("bulan lalu", "besok"), ("bulan lalu", "minggu depan"), ("bulan lalu", "bulan depan"),
            ("sekarang", "kemarin"), ("sekarang", "minggu lalu"), ("sekarang", "bulan lalu"),
            ("sekarang", "besok"), ("hari ini", "kemarin"), ("hari ini", "minggu lalu"),
            ("hari ini", "bulan lalu"), ("hari ini", "besok"), ("minggu ini", "minggu lalu"),
            ("minggu ini", "minggu depan"), ("bulan ini", "bulan lalu"), ("bulan ini", "bulan depan")
        ]
        self.temporal_conflict_sets = [frozenset(pair) for pair in temporal_conflicts]
        custom_log("INFO", "Logical rule sets have been pre-computed for efficiency.")


    def is_phrase_logically_valid(self, keywords_list: List[str]) -> bool:
        # Memeriksa apakah suatu frasa melanggar aturan logika yang telah ditentukan.
        keyword_set = set(keywords_list)

        if any(pair.issubset(keyword_set) for pair in self.antonym_sets): return False # Cek antonim
        if any(pair.issubset(keyword_set) for pair in self.temporal_conflict_sets): return False # Cek konflik waktu
        if any(pair.issubset(keyword_set) for pair in self.illogical_pair_sets): return False # Cek pasangan ilogis

        return True

    def validate_keyword_sequence(self, phrase: str) -> Optional[List[str]]:
        # Memastikan frasa yang dihasilkan LLM HANYA terdiri dari kata-kata yang ada di daftar KEYWORD (Mengatasi Model Halusinasi).
        temp_phrase = phrase.strip().lower()
        found_keywords = []
        while temp_phrase:
            match_found = False
            for keyword in self.sorted_keywords:
                # Mencocokkan kata kunci terpanjang terlebih dahulu (untuk menangani frasa majemuk seperti "air putih").
                if temp_phrase.startswith(keyword + " ") or temp_phrase == keyword:
                    found_keywords.append(keyword)
                    temp_phrase = temp_phrase[len(keyword):].strip() # Memotong kata kunci yang sudah dicocokkan.
                    match_found = True
                    break
            if not match_found:
                return None # Mengembalikan None jika ada kata yang TIDAK termasuk KEYWORDS.
        return found_keywords

    def _build_prompt(self, batch_size: int) -> str:
        # Membuat prompt yang sangat ketat untuk model LLM (Gemini).
        keyword_string = ", ".join(self.lowercase_keywords)
        return f"""
        PERHATIKAN: Anda adalah mesin generator data presisi tinggi. Kegagalan dalam mematuhi aturan format akan membuat output tidak dapat digunakan. Ikuti semua instruksi dengan sangat teliti.

        TUGAS UTAMA: Hasilkan {batch_size} baris kombinasi kata kunci.

        <ATURAN_SANGAT_PENTING>
        1. SETIAP KATA dalam output Anda HARUS, TANPA PENGECUALIAN, berasal dari daftar kata kunci yang diizinkan ini. JANGAN TAMBAHKAN KATA APAPUN di luar daftar.
        2. Setiap baris output HANYA berisi kata kunci yang dipisahkan oleh spasi. TIDAK BOLEH ada tanda baca, nomor, atau kata pengantar seperti "Berikut adalah...".
        3. Setiap baris harus berisi 2 hingga 6 kata kunci.
        4. Jangan ulangi kata kunci dalam satu baris.
        5. Semua kombinasi harus logis dan masuk akal dalam Bahasa Indonesia. Hindari kontradiksi (misal: "panas dingin", "kemarin besok").
        </<ATURAN_SANGAT_PENTING>
        
        <DAFTAR_KATA_KUNCI_YANG_DIIZINKAN>
        {keyword_string}
        </DAFTAR_KATA_KUNCI_YANG_DIIZINKAN>
        <CONTOH_OUTPUT_YANG_BENAR>
        saya lapar mau makan nasi sekarang
        adik laki-laki bermain komputer lagi
        nenek sedih hari ini
        tas ransel kotor
        ibu minum air putih
        burung hantu tidur siang
        rumah besar bersih
        </CONTOH_OUTPUT_YANG_BENAR>     
        """

    def generate(self):
        # Fungsi utama untuk menjalankan proses generasi dataset secara berulang (iteratif).
        custom_log("INFO", f"Starting dataset generation. Goal: {self.config.DATA_QUANTITY} unique phrases.")
        start_time = time.time()
        
        # Berjalan selama target kuantitas belum tercapai.
        while len(self.final_dataset) < self.config.DATA_QUANTITY:
            needed = self.config.DATA_QUANTITY - len(self.final_dataset)
            current_batch_size = min(self.config.BATCH_SIZE, needed)

            custom_log("INFO", f"Requesting {current_batch_size} new phrases. (Current unique total: {len(self.final_dataset)}/{self.config.DATA_QUANTITY})")

            llm_prompt = self._build_prompt(current_batch_size)
            
            # Logika percobaan ulang (retry) untuk mengatasi kegagalan API.
            for attempt in range(self.config.MAX_RETRIES):
                try:
                    response = self.model.generate_content(llm_prompt) # Memanggil LLM
                    llm_results = [result.strip() for result in response.text.strip().split('\n') if result.strip()]
                    newly_added_count = self._process_batch(llm_results) # Memproses dan memvalidasi hasil.

                    if newly_added_count > 0:
                        custom_log("INFO", f"Success. Added {newly_added_count} new valid phrases. New total: {len(self.final_dataset)}")
                        self._save_to_checkpoint()
                        time.sleep(self.config.SUCCESS_DELAY)
                        break # Lanjut ke iterasi berikutnya
                    else:
                        custom_log("WARNING", f"Attempt {attempt + 1}/{self.config.MAX_RETRIES}: Batch yielded 0 new valid phrases. Retrying...")
                        time.sleep(self.config.FAILURE_DELAY)
                except Exception as e:
                    custom_log("ERROR", f"Attempt {attempt + 1}/{self.config.MAX_RETRIES}: An API error occurred: {e}. Retrying in {self.config.FAILURE_DELAY}s...")
                    time.sleep(self.config.FAILURE_DELAY)
                    
        # Log akhir setelah selesai.
        total_time = time.time() - start_time
        print("---------------------------------------------------------")
        custom_log("INFO", "PROCESS COMPLETE!")
        custom_log("INFO", f"Total UNIQUE data points created: {len(self.final_dataset)}")
        custom_log("INFO", f"Total time elapsed: {total_time:.2f} seconds")

    def _process_batch(self, llm_results: List[str]) -> int:
        # Memvalidasi setiap frasa dari LLM dan menambahkannya ke dataset jika valid.
        initial_count = len(self.final_dataset)
        for result in llm_results:
            valid_tokens = self.validate_keyword_sequence(result)
            if not valid_tokens:
                continue
            
            # Cek 4 kriteria validasi keras:
            is_long_enough = self.config.MIN_PHRASE_LENGTH <= len(valid_tokens) <= self.config.MAX_PHRASE_LENGTH # 1. Panjang kata
            is_internal_unique = len(valid_tokens) == len(set(valid_tokens)) # 2. Tidak ada pengulangan kata
            is_logical = self.is_phrase_logically_valid(valid_tokens) # 3. Tidak ada konflik logika
            
            if is_long_enough and is_internal_unique and is_logical:
                self.final_dataset.add(tuple(valid_tokens)) # 4. Menambahkan ke set (otomatis cek keunikan)
                
        return len(self.final_dataset) - initial_count # Mengembalikan jumlah frasa baru yang berhasil ditambahkan.

    def save_to_file(self):
        # Menyimpan dataset final ke file dan menghapus checkpoint.
        if not self.final_dataset:
            custom_log("WARNING", "Final dataset is empty. Nothing to save.")
            return
            
        sorted_dataset = sorted(list(self.final_dataset))
        try:
            with open(self.config.OUTPUT_FILENAME, "w", encoding="utf-8") as f:
                for data_tuple in sorted_dataset:
                    formatted_keywords = [f'"{keyword}"' for keyword in data_tuple]
                    line = ", ".join(formatted_keywords)
                    f.write(line + "\n")
            custom_log("INFO", f"Dataset successfully saved to '{self.config.OUTPUT_FILENAME}'")
            
            # Menghapus file checkpoint karena proses sudah selesai.
            if os.path.exists(self.config.CHECKPOINT_FILENAME):
                os.remove(self.config.CHECKPOINT_FILENAME)
                custom_log("INFO", f"Checkpoint file '{self.config.CHECKPOINT_FILENAME}' removed.")
        except IOError as e:
            custom_log("ERROR", f"Failed to write to file '{self.config.OUTPUT_FILENAME}': {e}")


# --- Main Execution ---
def main():
    # Fungsi utama untuk menjalankan seluruh skrip.
    try:
        config = Config()
        generator = DatasetGenerator(config, KEYWORDS)
        generator.generate()
        generator.save_to_file()
    except NameError:
        custom_log("CRITICAL", "ERROR: Variable 'KEYWORDS' is not defined. ...")
    except Exception as e:
        custom_log("CRITICAL", f"A critical error occurred, and the script has to exit: {e}")

if __name__ == "__main__":
    # Memastikan main() hanya berjalan saat skrip dieksekusi langsung.
    main()
# Out:
# 2025-09-26 04:45:57 - INFO - Initializing Vertex AI for project 'talk-of-the-heart-aac-464912' in location 'us-central1'...
# 2025-09-26 04:45:57 - INFO - Successfully initialized Generative Model 'gemini-2.5-pro'.
# 2025-09-26 04:45:57 - INFO - Checkpoint file not found. Starting a new dataset.
# 2025-09-26 04:45:57 - INFO - Logical rule sets have been pre-computed for efficiency.
# 2025-09-26 04:45:57 - INFO - Starting dataset generation. Goal: 5000 unique phrases.
# 2025-09-26 04:45:57 - INFO - Requesting 150 new phrases. (Current unique total: 0/5000)
# /usr/local/lib/python3.12/dist-packages/vertexai/generative_models/_generative_models.py:433: UserWarning: This feature is deprecated as of June 24, 2025 and will be removed on June 24, 2026. For details, see https://cloud.google.com/vertex-ai/generative-ai/docs/deprecations/genai-vertexai-sdk.
#   warning_logs.show_deprecation_warning()
# /usr/local/lib/python3.12/dist-packages/google/auth/_default.py:76: UserWarning: Your application has authenticated using end user credentials from Google Cloud SDK without a quota project. You might receive a "quota exceeded" or "API not enabled" error. See the following page for troubleshooting: https://cloud.google.com/docs/authentication/adc-troubleshooting/user-creds.
#   warnings.warn(_CLOUD_SDK_CREDENTIALS_WARNING)
# 2025-09-26 04:47:12 - INFO - Success. Added 119 new valid phrases. New total: 119
# 2025-09-26 04:47:12 - INFO - Checkpoint saved with 119 records.
# 2025-09-26 04:47:13 - INFO - Requesting 150 new phrases. (Current unique total: 119/5000)
# 2025-09-26 04:48:22 - INFO - Success. Added 127 new valid phrases. New total: 246
# 2025-09-26 04:48:22 - INFO - Checkpoint saved with 246 records.
# 2025-09-26 04:48:22 - INFO - Requesting 150 new phrases. (Current unique total: 246/5000)
# 2025-09-26 04:49:02 - INFO - Success. Added 113 new valid phrases. New total: 359
# 2025-09-26 04:49:02 - INFO - Checkpoint saved with 359 records.
# 2025-09-26 04:49:02 - INFO - Requesting 150 new phrases. (Current unique total: 359/5000)
# 2025-09-26 04:50:04 - INFO - Success. Added 118 new valid phrases. New total: 477
# 2025-09-26 04:50:04 - INFO - Checkpoint saved with 477 records.
# 2025-09-26 04:50:05 - INFO - Requesting 150 new phrases. (Current unique total: 477/5000)
# 2025-09-26 04:51:03 - INFO - Success. Added 44 new valid phrases. New total: 521
# 2025-09-26 04:51:03 - INFO - Checkpoint saved with 521 records.
# 2025-09-26 04:51:03 - INFO - Requesting 150 new phrases. (Current unique total: 521/5000)
# 2025-09-26 04:51:53 - INFO - Success. Added 22 new valid phrases. New total: 543
# 2025-09-26 04:51:53 - INFO - Checkpoint saved with 543 records.
# 2025-09-26 04:51:53 - INFO - Requesting 150 new phrases. (Current unique total: 543/5000)
# 2025-09-26 04:53:20 - INFO - Success. Added 28 new valid phrases. New total: 571
# 2025-09-26 04:53:20 - INFO - Checkpoint saved with 571 records.
# 2025-09-26 04:53:20 - INFO - Requesting 150 new phrases. (Current unique total: 571/5000)
# 2025-09-26 04:54:23 - INFO - Success. Added 57 new valid phrases. New total: 628
# 2025-09-26 04:54:23 - INFO - Checkpoint saved with 628 records.
# 2025-09-26 04:54:23 - INFO - Requesting 150 new phrases. (Current unique total: 628/5000)
# 2025-09-26 04:55:33 - INFO - Success. Added 94 new valid phrases. New total: 722
# 2025-09-26 04:55:33 - INFO - Checkpoint saved with 722 records.
# 2025-09-26 04:55:33 - INFO - Requesting 150 new phrases. (Current unique total: 722/5000)
# 2025-09-26 04:55:36 - ERROR - Attempt 1/5: An API error occurred: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.. Retrying in 10s...
# 2025-09-26 04:56:43 - INFO - Success. Added 84 new valid phrases. New total: 806
# 2025-09-26 04:56:43 - INFO - Checkpoint saved with 806 records.
# 2025-09-26 04:56:44 - INFO - Requesting 150 new phrases. (Current unique total: 806/5000)
# 2025-09-26 04:57:33 - INFO - Success. Added 86 new valid phrases. New total: 892
# 2025-09-26 04:57:33 - INFO - Checkpoint saved with 892 records.
# 2025-09-26 04:57:34 - INFO - Requesting 150 new phrases. (Current unique total: 892/5000)
# 2025-09-26 04:58:29 - INFO - Success. Added 88 new valid phrases. New total: 980
# 2025-09-26 04:58:29 - INFO - Checkpoint saved with 980 records.
# 2025-09-26 04:58:29 - INFO - Requesting 150 new phrases. (Current unique total: 980/5000)
# 2025-09-26 04:59:23 - INFO - Success. Added 41 new valid phrases. New total: 1021
# 2025-09-26 04:59:23 - INFO - Checkpoint saved with 1021 records.
# 2025-09-26 04:59:24 - INFO - Requesting 150 new phrases. (Current unique total: 1021/5000)
# 2025-09-26 05:00:03 - INFO - Success. Added 89 new valid phrases. New total: 1110
# 2025-09-26 05:00:03 - INFO - Checkpoint saved with 1110 records.
# 2025-09-26 05:00:04 - INFO - Requesting 150 new phrases. (Current unique total: 1110/5000)
# 2025-09-26 05:00:42 - INFO - Success. Added 71 new valid phrases. New total: 1181
# 2025-09-26 05:00:42 - INFO - Checkpoint saved with 1181 records.
# 2025-09-26 05:00:43 - INFO - Requesting 150 new phrases. (Current unique total: 1181/5000)
# 2025-09-26 05:01:49 - INFO - Success. Added 66 new valid phrases. New total: 1247
# 2025-09-26 05:01:49 - INFO - Checkpoint saved with 1247 records.
# 2025-09-26 05:01:50 - INFO - Requesting 150 new phrases. (Current unique total: 1247/5000)
# 2025-09-26 05:03:09 - INFO - Success. Added 78 new valid phrases. New total: 1325
# 2025-09-26 05:03:09 - INFO - Checkpoint saved with 1325 records.
# 2025-09-26 05:03:09 - INFO - Requesting 150 new phrases. (Current unique total: 1325/5000)
# 2025-09-26 05:04:06 - INFO - Success. Added 62 new valid phrases. New total: 1387
# 2025-09-26 05:04:06 - INFO - Checkpoint saved with 1387 records.
# 2025-09-26 05:04:07 - INFO - Requesting 150 new phrases. (Current unique total: 1387/5000)
# 2025-09-26 05:04:53 - INFO - Success. Added 91 new valid phrases. New total: 1478
# 2025-09-26 05:04:53 - INFO - Checkpoint saved with 1478 records.
# 2025-09-26 05:04:53 - INFO - Requesting 150 new phrases. (Current unique total: 1478/5000)
# 2025-09-26 05:05:48 - INFO - Success. Added 78 new valid phrases. New total: 1556
# 2025-09-26 05:05:48 - INFO - Checkpoint saved with 1556 records.
# 2025-09-26 05:05:49 - INFO - Requesting 150 new phrases. (Current unique total: 1556/5000)
# 2025-09-26 05:06:21 - INFO - Success. Added 5 new valid phrases. New total: 1561
# 2025-09-26 05:06:21 - INFO - Checkpoint saved with 1561 records.
# 2025-09-26 05:06:21 - INFO - Requesting 150 new phrases. (Current unique total: 1561/5000)
# 2025-09-26 05:07:11 - INFO - Success. Added 75 new valid phrases. New total: 1636
# 2025-09-26 05:07:11 - INFO - Checkpoint saved with 1636 records.
# 2025-09-26 05:07:11 - INFO - Requesting 150 new phrases. (Current unique total: 1636/5000)
# 2025-09-26 05:08:07 - INFO - Success. Added 59 new valid phrases. New total: 1695
# 2025-09-26 05:08:07 - INFO - Checkpoint saved with 1695 records.
# 2025-09-26 05:08:08 - INFO - Requesting 150 new phrases. (Current unique total: 1695/5000)
# 2025-09-26 05:09:07 - INFO - Success. Added 64 new valid phrases. New total: 1759
# 2025-09-26 05:09:07 - INFO - Checkpoint saved with 1759 records.
# 2025-09-26 05:09:07 - INFO - Requesting 150 new phrases. (Current unique total: 1759/5000)
# 2025-09-26 05:09:35 - INFO - Success. Added 12 new valid phrases. New total: 1771
# 2025-09-26 05:09:35 - INFO - Checkpoint saved with 1771 records.
# 2025-09-26 05:09:35 - INFO - Requesting 150 new phrases. (Current unique total: 1771/5000)
# 2025-09-26 05:10:15 - INFO - Success. Added 10 new valid phrases. New total: 1781
# 2025-09-26 05:10:15 - INFO - Checkpoint saved with 1781 records.
# 2025-09-26 05:10:15 - INFO - Requesting 150 new phrases. (Current unique total: 1781/5000)
# 2025-09-26 05:11:01 - INFO - Success. Added 32 new valid phrases. New total: 1813
# 2025-09-26 05:11:01 - INFO - Checkpoint saved with 1813 records.
# 2025-09-26 05:11:01 - INFO - Requesting 150 new phrases. (Current unique total: 1813/5000)
# 2025-09-26 05:12:05 - INFO - Success. Added 23 new valid phrases. New total: 1836
# 2025-09-26 05:12:05 - INFO - Checkpoint saved with 1836 records.
# 2025-09-26 05:12:05 - INFO - Requesting 150 new phrases. (Current unique total: 1836/5000)
# 2025-09-26 05:13:02 - INFO - Success. Added 71 new valid phrases. New total: 1907
# 2025-09-26 05:13:02 - INFO - Checkpoint saved with 1907 records.
# 2025-09-26 05:13:02 - INFO - Requesting 150 new phrases. (Current unique total: 1907/5000)
# 2025-09-26 05:13:59 - INFO - Success. Added 82 new valid phrases. New total: 1989
# 2025-09-26 05:13:59 - INFO - Checkpoint saved with 1989 records.
# 2025-09-26 05:13:59 - INFO - Requesting 150 new phrases. (Current unique total: 1989/5000)
# 2025-09-26 05:14:45 - INFO - Success. Added 51 new valid phrases. New total: 2040
# 2025-09-26 05:14:45 - INFO - Checkpoint saved with 2040 records.
# 2025-09-26 05:14:46 - INFO - Requesting 150 new phrases. (Current unique total: 2040/5000)
# 2025-09-26 05:16:01 - INFO - Success. Added 61 new valid phrases. New total: 2101
# 2025-09-26 05:16:02 - INFO - Checkpoint saved with 2101 records.
# 2025-09-26 05:16:02 - INFO - Requesting 150 new phrases. (Current unique total: 2101/5000)
# 2025-09-26 05:17:09 - INFO - Success. Added 57 new valid phrases. New total: 2158
# 2025-09-26 05:17:09 - INFO - Checkpoint saved with 2158 records.
# 2025-09-26 05:17:10 - INFO - Requesting 150 new phrases. (Current unique total: 2158/5000)
# 2025-09-26 05:18:08 - INFO - Success. Added 32 new valid phrases. New total: 2190
# 2025-09-26 05:18:08 - INFO - Checkpoint saved with 2190 records.
# 2025-09-26 05:18:09 - INFO - Requesting 150 new phrases. (Current unique total: 2190/5000)
# 2025-09-26 05:18:12 - ERROR - Attempt 1/5: An API error occurred: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.. Retrying in 10s...
# 2025-09-26 05:18:46 - INFO - Success. Added 15 new valid phrases. New total: 2205
# 2025-09-26 05:18:46 - INFO - Checkpoint saved with 2205 records.
# 2025-09-26 05:18:46 - INFO - Requesting 150 new phrases. (Current unique total: 2205/5000)
# 2025-09-26 05:19:33 - INFO - Success. Added 61 new valid phrases. New total: 2266
# 2025-09-26 05:19:33 - INFO - Checkpoint saved with 2266 records.
# 2025-09-26 05:19:33 - INFO - Requesting 150 new phrases. (Current unique total: 2266/5000)
# 2025-09-26 05:20:23 - INFO - Success. Added 46 new valid phrases. New total: 2312
# 2025-09-26 05:20:23 - INFO - Checkpoint saved with 2312 records.
# 2025-09-26 05:20:23 - INFO - Requesting 150 new phrases. (Current unique total: 2312/5000)
# 2025-09-26 05:21:24 - INFO - Success. Added 40 new valid phrases. New total: 2352
# 2025-09-26 05:21:24 - INFO - Checkpoint saved with 2352 records.
# 2025-09-26 05:21:25 - INFO - Requesting 150 new phrases. (Current unique total: 2352/5000)
# 2025-09-26 05:22:08 - INFO - Success. Added 53 new valid phrases. New total: 2405
# 2025-09-26 05:22:08 - INFO - Checkpoint saved with 2405 records.
# 2025-09-26 05:22:09 - INFO - Requesting 150 new phrases. (Current unique total: 2405/5000)
# 2025-09-26 05:22:13 - ERROR - Attempt 1/5: An API error occurred: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.. Retrying in 10s...
# 2025-09-26 05:22:26 - ERROR - Attempt 2/5: An API error occurred: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.. Retrying in 10s...
# 2025-09-26 05:23:33 - INFO - Success. Added 44 new valid phrases. New total: 2449
# 2025-09-26 05:23:33 - INFO - Checkpoint saved with 2449 records.
# 2025-09-26 05:23:33 - INFO - Requesting 150 new phrases. (Current unique total: 2449/5000)
# 2025-09-26 05:24:39 - INFO - Success. Added 59 new valid phrases. New total: 2508
# 2025-09-26 05:24:39 - INFO - Checkpoint saved with 2508 records.
# 2025-09-26 05:24:40 - INFO - Requesting 150 new phrases. (Current unique total: 2508/5000)
# 2025-09-26 05:25:25 - INFO - Success. Added 72 new valid phrases. New total: 2580
# 2025-09-26 05:25:25 - INFO - Checkpoint saved with 2580 records.
# 2025-09-26 05:25:26 - INFO - Requesting 150 new phrases. (Current unique total: 2580/5000)
# 2025-09-26 05:26:25 - INFO - Success. Added 52 new valid phrases. New total: 2632
# 2025-09-26 05:26:25 - INFO - Checkpoint saved with 2632 records.
# 2025-09-26 05:26:26 - INFO - Requesting 150 new phrases. (Current unique total: 2632/5000)
# 2025-09-26 05:27:10 - INFO - Success. Added 35 new valid phrases. New total: 2667
# 2025-09-26 05:27:10 - INFO - Checkpoint saved with 2667 records.
# 2025-09-26 05:27:10 - INFO - Requesting 150 new phrases. (Current unique total: 2667/5000)
# 2025-09-26 05:28:05 - INFO - Success. Added 23 new valid phrases. New total: 2690
# 2025-09-26 05:28:05 - INFO - Checkpoint saved with 2690 records.
# 2025-09-26 05:28:06 - INFO - Requesting 150 new phrases. (Current unique total: 2690/5000)
# 2025-09-26 05:29:02 - INFO - Success. Added 28 new valid phrases. New total: 2718
# 2025-09-26 05:29:02 - INFO - Checkpoint saved with 2718 records.
# 2025-09-26 05:29:03 - INFO - Requesting 150 new phrases. (Current unique total: 2718/5000)
# 2025-09-26 05:29:53 - INFO - Success. Added 49 new valid phrases. New total: 2767
# 2025-09-26 05:29:53 - INFO - Checkpoint saved with 2767 records.
# 2025-09-26 05:29:54 - INFO - Requesting 150 new phrases. (Current unique total: 2767/5000)
# 2025-09-26 05:30:37 - INFO - Success. Added 33 new valid phrases. New total: 2800
# 2025-09-26 05:30:37 - INFO - Checkpoint saved with 2800 records.
# 2025-09-26 05:30:38 - INFO - Requesting 150 new phrases. (Current unique total: 2800/5000)
# 2025-09-26 05:31:31 - INFO - Success. Added 28 new valid phrases. New total: 2828
# 2025-09-26 05:31:31 - INFO - Checkpoint saved with 2828 records.
# 2025-09-26 05:31:31 - INFO - Requesting 150 new phrases. (Current unique total: 2828/5000)
# 2025-09-26 05:32:15 - INFO - Success. Added 6 new valid phrases. New total: 2834
# 2025-09-26 05:32:15 - INFO - Checkpoint saved with 2834 records.
# 2025-09-26 05:32:16 - INFO - Requesting 150 new phrases. (Current unique total: 2834/5000)
# 2025-09-26 05:32:17 - ERROR - Attempt 1/5: An API error occurred: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.. Retrying in 10s...
# 2025-09-26 05:33:23 - INFO - Success. Added 33 new valid phrases. New total: 2867
# 2025-09-26 05:33:23 - INFO - Checkpoint saved with 2867 records.
# 2025-09-26 05:33:24 - INFO - Requesting 150 new phrases. (Current unique total: 2867/5000)
# 2025-09-26 05:34:09 - INFO - Success. Added 29 new valid phrases. New total: 2896
# 2025-09-26 05:34:09 - INFO - Checkpoint saved with 2896 records.
# 2025-09-26 05:34:09 - INFO - Requesting 150 new phrases. (Current unique total: 2896/5000)
# 2025-09-26 05:35:03 - INFO - Success. Added 38 new valid phrases. New total: 2934
# 2025-09-26 05:35:03 - INFO - Checkpoint saved with 2934 records.
# 2025-09-26 05:35:04 - INFO - Requesting 150 new phrases. (Current unique total: 2934/5000)
# 2025-09-26 05:35:06 - ERROR - Attempt 1/5: An API error occurred: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.. Retrying in 10s...
# 2025-09-26 05:36:02 - INFO - Success. Added 40 new valid phrases. New total: 2974
# 2025-09-26 05:36:02 - INFO - Checkpoint saved with 2974 records.
# 2025-09-26 05:36:03 - INFO - Requesting 150 new phrases. (Current unique total: 2974/5000)
# 2025-09-26 05:36:04 - ERROR - Attempt 1/5: An API error occurred: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.. Retrying in 10s...
# 2025-09-26 05:36:48 - INFO - Success. Added 39 new valid phrases. New total: 3013
# 2025-09-26 05:36:48 - INFO - Checkpoint saved with 3013 records.
# 2025-09-26 05:36:49 - INFO - Requesting 150 new phrases. (Current unique total: 3013/5000)
# 2025-09-26 05:37:52 - INFO - Success. Added 55 new valid phrases. New total: 3068
# 2025-09-26 05:37:52 - INFO - Checkpoint saved with 3068 records.
# 2025-09-26 05:37:53 - INFO - Requesting 150 new phrases. (Current unique total: 3068/5000)
# 2025-09-26 05:38:43 - INFO - Success. Added 26 new valid phrases. New total: 3094
# 2025-09-26 05:38:43 - INFO - Checkpoint saved with 3094 records.
# 2025-09-26 05:38:43 - INFO - Requesting 150 new phrases. (Current unique total: 3094/5000)
# 2025-09-26 05:39:23 - INFO - Success. Added 22 new valid phrases. New total: 3116
# 2025-09-26 05:39:23 - INFO - Checkpoint saved with 3116 records.
# 2025-09-26 05:39:24 - INFO - Requesting 150 new phrases. (Current unique total: 3116/5000)
# 2025-09-26 05:40:02 - INFO - Success. Added 26 new valid phrases. New total: 3142
# 2025-09-26 05:40:02 - INFO - Checkpoint saved with 3142 records.
# 2025-09-26 05:40:03 - INFO - Requesting 150 new phrases. (Current unique total: 3142/5000)
# 2025-09-26 05:40:55 - INFO - Success. Added 40 new valid phrases. New total: 3182
# 2025-09-26 05:40:55 - INFO - Checkpoint saved with 3182 records.
# 2025-09-26 05:40:56 - INFO - Requesting 150 new phrases. (Current unique total: 3182/5000)
# 2025-09-26 05:41:39 - INFO - Success. Added 26 new valid phrases. New total: 3208
# 2025-09-26 05:41:39 - INFO - Checkpoint saved with 3208 records.
# 2025-09-26 05:41:39 - INFO - Requesting 150 new phrases. (Current unique total: 3208/5000)
# 2025-09-26 05:42:17 - INFO - Success. Added 23 new valid phrases. New total: 3231
# 2025-09-26 05:42:17 - INFO - Checkpoint saved with 3231 records.
# 2025-09-26 05:42:17 - INFO - Requesting 150 new phrases. (Current unique total: 3231/5000)
# 2025-09-26 05:43:14 - INFO - Success. Added 32 new valid phrases. New total: 3263
# 2025-09-26 05:43:14 - INFO - Checkpoint saved with 3263 records.
# 2025-09-26 05:43:15 - INFO - Requesting 150 new phrases. (Current unique total: 3263/5000)
# 2025-09-26 05:44:35 - INFO - Success. Added 56 new valid phrases. New total: 3319
# 2025-09-26 05:44:35 - INFO - Checkpoint saved with 3319 records.
# 2025-09-26 05:44:35 - INFO - Requesting 150 new phrases. (Current unique total: 3319/5000)
# 2025-09-26 05:45:24 - INFO - Success. Added 33 new valid phrases. New total: 3352
# 2025-09-26 05:45:24 - INFO - Checkpoint saved with 3352 records.
# 2025-09-26 05:45:25 - INFO - Requesting 150 new phrases. (Current unique total: 3352/5000)
# 2025-09-26 05:46:42 - INFO - Success. Added 44 new valid phrases. New total: 3396
# 2025-09-26 05:46:42 - INFO - Checkpoint saved with 3396 records.
# 2025-09-26 05:46:43 - INFO - Requesting 150 new phrases. (Current unique total: 3396/5000)
# 2025-09-26 05:47:41 - INFO - Success. Added 45 new valid phrases. New total: 3441
# 2025-09-26 05:47:41 - INFO - Checkpoint saved with 3441 records.
# 2025-09-26 05:47:41 - INFO - Requesting 150 new phrases. (Current unique total: 3441/5000)
# 2025-09-26 05:48:54 - INFO - Success. Added 47 new valid phrases. New total: 3488
# 2025-09-26 05:48:54 - INFO - Checkpoint saved with 3488 records.
# 2025-09-26 05:48:54 - INFO - Requesting 150 new phrases. (Current unique total: 3488/5000)
# 2025-09-26 05:49:54 - INFO - Success. Added 30 new valid phrases. New total: 3518
# 2025-09-26 05:49:54 - INFO - Checkpoint saved with 3518 records.
# 2025-09-26 05:49:55 - INFO - Requesting 150 new phrases. (Current unique total: 3518/5000)
# 2025-09-26 05:50:50 - INFO - Success. Added 42 new valid phrases. New total: 3560
# 2025-09-26 05:50:50 - INFO - Checkpoint saved with 3560 records.
# 2025-09-26 05:50:51 - INFO - Requesting 150 new phrases. (Current unique total: 3560/5000)
# 2025-09-26 05:51:50 - INFO - Success. Added 24 new valid phrases. New total: 3584
# 2025-09-26 05:51:50 - INFO - Checkpoint saved with 3584 records.
# 2025-09-26 05:51:50 - INFO - Requesting 150 new phrases. (Current unique total: 3584/5000)
# 2025-09-26 05:52:02 - ERROR - Attempt 1/5: An API error occurred: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.. Retrying in 10s...
# 2025-09-26 05:53:03 - INFO - Success. Added 44 new valid phrases. New total: 3628
# 2025-09-26 05:53:03 - INFO - Checkpoint saved with 3628 records.
# 2025-09-26 05:53:03 - INFO - Requesting 150 new phrases. (Current unique total: 3628/5000)
# 2025-09-26 05:54:03 - INFO - Success. Added 36 new valid phrases. New total: 3664
# 2025-09-26 05:54:03 - INFO - Checkpoint saved with 3664 records.
# 2025-09-26 05:54:03 - INFO - Requesting 150 new phrases. (Current unique total: 3664/5000)
# 2025-09-26 05:55:17 - INFO - Success. Added 59 new valid phrases. New total: 3723
# 2025-09-26 05:55:17 - INFO - Checkpoint saved with 3723 records.
# 2025-09-26 05:55:18 - INFO - Requesting 150 new phrases. (Current unique total: 3723/5000)
# 2025-09-26 05:55:24 - ERROR - Attempt 1/5: An API error occurred: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.. Retrying in 10s...
# 2025-09-26 05:56:20 - INFO - Success. Added 12 new valid phrases. New total: 3735
# 2025-09-26 05:56:20 - INFO - Checkpoint saved with 3735 records.
# 2025-09-26 05:56:20 - INFO - Requesting 150 new phrases. (Current unique total: 3735/5000)
# 2025-09-26 05:57:25 - INFO - Success. Added 20 new valid phrases. New total: 3755
# 2025-09-26 05:57:25 - INFO - Checkpoint saved with 3755 records.
# 2025-09-26 05:57:25 - INFO - Requesting 150 new phrases. (Current unique total: 3755/5000)
# 2025-09-26 05:58:33 - INFO - Success. Added 34 new valid phrases. New total: 3789
# 2025-09-26 05:58:33 - INFO - Checkpoint saved with 3789 records.
# 2025-09-26 05:58:34 - INFO - Requesting 150 new phrases. (Current unique total: 3789/5000)
# 2025-09-26 05:59:31 - INFO - Success. Added 29 new valid phrases. New total: 3818
# 2025-09-26 05:59:31 - INFO - Checkpoint saved with 3818 records.
# 2025-09-26 05:59:32 - INFO - Requesting 150 new phrases. (Current unique total: 3818/5000)
# 2025-09-26 06:00:18 - INFO - Success. Added 25 new valid phrases. New total: 3843
# 2025-09-26 06:00:18 - INFO - Checkpoint saved with 3843 records.
# 2025-09-26 06:00:18 - INFO - Requesting 150 new phrases. (Current unique total: 3843/5000)
# 2025-09-26 06:01:32 - INFO - Success. Added 30 new valid phrases. New total: 3873
# 2025-09-26 06:01:32 - INFO - Checkpoint saved with 3873 records.
# 2025-09-26 06:01:33 - INFO - Requesting 150 new phrases. (Current unique total: 3873/5000)
# 2025-09-26 06:02:13 - INFO - Success. Added 37 new valid phrases. New total: 3910
# 2025-09-26 06:02:13 - INFO - Checkpoint saved with 3910 records.
# 2025-09-26 06:02:13 - INFO - Requesting 150 new phrases. (Current unique total: 3910/5000)
# 2025-09-26 06:03:07 - INFO - Success. Added 32 new valid phrases. New total: 3942
# 2025-09-26 06:03:07 - INFO - Checkpoint saved with 3942 records.
# 2025-09-26 06:03:08 - INFO - Requesting 150 new phrases. (Current unique total: 3942/5000)
# 2025-09-26 06:03:44 - INFO - Success. Added 34 new valid phrases. New total: 3976
# 2025-09-26 06:03:44 - INFO - Checkpoint saved with 3976 records.
# 2025-09-26 06:03:45 - INFO - Requesting 150 new phrases. (Current unique total: 3976/5000)
# 2025-09-26 06:04:23 - INFO - Success. Added 22 new valid phrases. New total: 3998
# 2025-09-26 06:04:23 - INFO - Checkpoint saved with 3998 records.
# 2025-09-26 06:04:23 - INFO - Requesting 150 new phrases. (Current unique total: 3998/5000)
# 2025-09-26 06:05:25 - INFO - Success. Added 22 new valid phrases. New total: 4020
# 2025-09-26 06:05:25 - INFO - Checkpoint saved with 4020 records.
# 2025-09-26 06:05:25 - INFO - Requesting 150 new phrases. (Current unique total: 4020/5000)
# 2025-09-26 06:05:50 - INFO - Success. Added 4 new valid phrases. New total: 4024
# 2025-09-26 06:05:50 - INFO - Checkpoint saved with 4024 records.
# 2025-09-26 06:05:51 - INFO - Requesting 150 new phrases. (Current unique total: 4024/5000)
# 2025-09-26 06:06:56 - INFO - Success. Added 47 new valid phrases. New total: 4071
# 2025-09-26 06:06:56 - INFO - Checkpoint saved with 4071 records.
# 2025-09-26 06:06:56 - INFO - Requesting 150 new phrases. (Current unique total: 4071/5000)
# 2025-09-26 06:07:23 - INFO - Success. Added 18 new valid phrases. New total: 4089
# 2025-09-26 06:07:23 - INFO - Checkpoint saved with 4089 records.
# 2025-09-26 06:07:24 - INFO - Requesting 150 new phrases. (Current unique total: 4089/5000)
# 2025-09-26 06:08:07 - INFO - Success. Added 19 new valid phrases. New total: 4108
# 2025-09-26 06:08:07 - INFO - Checkpoint saved with 4108 records.
# 2025-09-26 06:08:08 - INFO - Requesting 150 new phrases. (Current unique total: 4108/5000)
# 2025-09-26 06:08:49 - INFO - Success. Added 21 new valid phrases. New total: 4129
# 2025-09-26 06:08:49 - INFO - Checkpoint saved with 4129 records.
# 2025-09-26 06:08:50 - INFO - Requesting 150 new phrases. (Current unique total: 4129/5000)
# 2025-09-26 06:09:47 - INFO - Success. Added 29 new valid phrases. New total: 4158
# 2025-09-26 06:09:47 - INFO - Checkpoint saved with 4158 records.
# 2025-09-26 06:09:48 - INFO - Requesting 150 new phrases. (Current unique total: 4158/5000)
# 2025-09-26 06:10:13 - INFO - Success. Added 16 new valid phrases. New total: 4174
# 2025-09-26 06:10:13 - INFO - Checkpoint saved with 4174 records.
# 2025-09-26 06:10:14 - INFO - Requesting 150 new phrases. (Current unique total: 4174/5000)
# 2025-09-26 06:11:06 - INFO - Success. Added 20 new valid phrases. New total: 4194
# 2025-09-26 06:11:06 - INFO - Checkpoint saved with 4194 records.
# 2025-09-26 06:11:06 - INFO - Requesting 150 new phrases. (Current unique total: 4194/5000)
# 2025-09-26 06:11:09 - ERROR - Attempt 1/5: An API error occurred: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.. Retrying in 10s...
# 2025-09-26 06:12:05 - INFO - Success. Added 31 new valid phrases. New total: 4225
# 2025-09-26 06:12:05 - INFO - Checkpoint saved with 4225 records.
# 2025-09-26 06:12:05 - INFO - Requesting 150 new phrases. (Current unique total: 4225/5000)
# 2025-09-26 06:13:06 - INFO - Success. Added 24 new valid phrases. New total: 4249
# 2025-09-26 06:13:06 - INFO - Checkpoint saved with 4249 records.
# 2025-09-26 06:13:07 - INFO - Requesting 150 new phrases. (Current unique total: 4249/5000)
# 2025-09-26 06:13:46 - INFO - Success. Added 27 new valid phrases. New total: 4276
# 2025-09-26 06:13:46 - INFO - Checkpoint saved with 4276 records.
# 2025-09-26 06:13:47 - INFO - Requesting 150 new phrases. (Current unique total: 4276/5000)
# 2025-09-26 06:13:48 - ERROR - Attempt 1/5: An API error occurred: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.. Retrying in 10s...
# 2025-09-26 06:14:40 - INFO - Success. Added 10 new valid phrases. New total: 4286
# 2025-09-26 06:14:40 - INFO - Checkpoint saved with 4286 records.
# 2025-09-26 06:14:40 - INFO - Requesting 150 new phrases. (Current unique total: 4286/5000)
# 2025-09-26 06:15:37 - INFO - Success. Added 35 new valid phrases. New total: 4321
# 2025-09-26 06:15:37 - INFO - Checkpoint saved with 4321 records.
# 2025-09-26 06:15:38 - INFO - Requesting 150 new phrases. (Current unique total: 4321/5000)
# 2025-09-26 06:16:34 - INFO - Success. Added 36 new valid phrases. New total: 4357
# 2025-09-26 06:16:34 - INFO - Checkpoint saved with 4357 records.
# 2025-09-26 06:16:35 - INFO - Requesting 150 new phrases. (Current unique total: 4357/5000)
# 2025-09-26 06:18:15 - ERROR - Attempt 1/5: An API error occurred: Cannot get the response text.
# Cannot get the Candidate text.
# Multiple content parts are not supported.
# Candidate:
# {
#   "content": {
#     "role": "model",
#     "parts": [
#       {
#         "text": "saya lapar mau makan nasi\nibu minum air putih dingin\nayah lihat tv malam ini\nkakak laki-laki bermain komputer lagi\nadik perempuan sedang tidur siang\nkucing kecil bermain di rumah (Correction: 'di' and 'rumah' are valid keywords. I will use them) -> kucing kecil bermain rumah\nrumah besar bersih\ntas ransel kotor buruk\nnenek sedih hari ini\nkakek senang lihat burung\nkamu haus mau minum susu\nadik laki-laki mau es krim cokelat\nkakak perempuan lihat handphone sekarang\nini bukan buku saya (Correction: 'saya' is a keyword. This is valid) -> ini bukan buku\nini rumah besar sekali (Correction: 'sekali' is not a keyword) -> ini rumah besar\nburung hantu tidak tidur pagi\nmonyet makan pisang di pohon (Correction: 'di' and 'pohon' are not keywords) -> monyet makan pisang\ngajah minum banyak air putih\nmusim kemarau sangat panas (Correction: 'sangat' is not a keyword) -> musim kemarau panas terik\nmusim hujan dingin berawan\nsaya sedang bingung sekarang\nkamu tidak sakit lagi\nsup ayam ini panas (Correction: 'ayam' and 'ini' are keywords, but 'sup ayam' is a compound. I'll stick to single keywords) -> sup panas\nes krim cokelat dingin\napel anggur pisang semangka\nmakan banyak buah-buahan\npiring mangkuk gelas bersih\nsendok garpu pisau tajam (Correction: 'tajam' is not a keyword) -> sendok garpu pisau\nsaya sedang makan mie ayam (Correction: 'mie ayam' is not a keyword) -> saya sedang makan mie\nayah minum susu cokelat panas\nibu mau makan sup ikan\nkelinci kecil takut anjing\nberuang besar sedang lapar\npenguin lihat banyak ikan\npenyu kura-kura berenang (Correction: 'berenang' is not a keyword) -> penyu kura-kura\nsaya mau pensil warna baru (Correction: 'baru' is not a keyword) -> saya mau pensil warna\nkertas origami tipis bagus\nmau gunting lem kertas\nkomputer laptop tablet bagus\nremot kontrol untuk tv (Correction: 'untuk' is not a keyword) -> remot kontrol tv\nkipas angin tidak dingin\nkulkas besar dingin bagus\nhalo terima kasih\nsampai jumpa besok pagi\nadik perempuan bermain origami\nkakak laki-laki dengar kamu\nsaya tidak dengar kamu bicara\nayam goreng kentang goreng enak (Correction: 'enak' is not a keyword) -> ayam goreng kentang goreng\nmakan nasi telur goreng tempe\nkamu jangan marah (Correction: 'jangan' is not a keyword) -> kamu marah\nsaya tidak sedang marah\nwaktu makan siang sekarang\nakhir pekan mau bermain\nbulan lalu hujan badai\nbulan depan musim kemarau\nminggu ini cuaca berawan (Correction: 'cuaca' is not a keyword) -> minggu ini berawan\nkemarin saya sakit kepala (Correction: 'kepala' is not a keyword) -> kemarin saya sakit\nsekarang saya senang lagi\nkatak kecil di kolam (Correction: 'di' and 'kolam' are not keywords) -> katak kecil\nrubah lihat ayam bebek\ntikus kecil makan keripik\nsapi domba babi\nikan berenang di air (Correction: 'berenang' and 'di' are not keywords) -> ikan di air putih (not logical) -> ikan banyak\nini kamera digital bagus (Correction: 'digital' is not a keyword) -> ini kamera bagus\njam tangan saya rusak (Correction: 'tangan' and 'rusak' are not keywords) -> jam buruk\nini jam buruk sekali (Correction: 'sekali' is not a keyword) -> ini jam buruk\nalpukat cokelat susu stroberi\njus jeruk tidak cukup dingin\nroti gandum tebal (Correction: 'gandum' is not a keyword) -> roti tebal\npermen stroberi cokelat\nhamburger besar dan enak (Correction: 'dan' and 'enak' are not keywords) -> hamburger besar\nsaya mau bicara dengan kamu (Correction: 'dengan' is not a keyword) -> saya mau bicara kamu\nadik laki-laki tidak bisa bicara\nayah mau tidur siang\nibu sedang makan buah alpukat\nkakek lihat burung hantu\nnenek minum susu hangat (Correction: 'hangat' is not a keyword) -> nenek minum susu\nsaya mau tas ransel itu (Correction: 'itu' is not a keyword) -> saya mau tas ransel\nkamu mau pensil rautan\nbuku tulis tipis (Correction: 'tulis' is not a keyword) -> buku tipis\npenggaris pensil kertas lem\nkoala tidur di atas pohon (Correction: 'di' 'atas' 'pohon' are not keywords) ...
#       },
#       {
#         "text": "saya lapar mau makan nasi\nibu minum air putih dingin\nayah lihat tv malam\nkakak laki-laki bermain komputer\nadik perempuan sedang tidur\nkucing kecil bermain lagi\nanjing besar makan roti\nhari ini matahari terik\nbesok pagi hujan\nbuku ini tebal bagus\ntas ransel kotor buruk\nnenek sedih hari ini\nkakek senang lihat burung\nsaya mau makan ayam goreng\nkamu haus mau minum susu\nadik laki-laki mau es krim\nkakak perempuan lihat handphone\nini bukan buku kamu\nrumah besar bersih\nburung hantu tidak tidur\nmonyet makan pisang\ngajah minum banyak air putih\nmusim kemarau panas\nmusim hujan dingin\nsaya sedang bingung\nkamu tidak sakit\nsup panas\nes krim cokelat dingin\napel anggur semangka pisang\nmakan banyak buah-buahan\npiring mangkuk gelas bersih\nsendok garpu pisau\nsaya sedang makan mie\nayah minum susu cokelat\nibu mau makan sup\nkelinci kecil takut\nberuang besar lapar\npenguin lihat ikan\npenyu kura-kura\nsaya mau pensil warna\nkertas origami tipis\nmau gunting lem\nkomputer laptop tablet\nremot kontrol ac\nkipas angin tidak dingin\nkulkas besar bagus\ntoilet kotor\nhalo terima kasih\nsampai jumpa besok\nadik perempuan bermain origami\nkakak laki-laki dengar kamu\nsaya tidak dengar kamu\nayam goreng kentang goreng\nmakan nasi telur goreng\nkamu marah lagi\nsaya tidak sedang marah\nwaktu makan siang\nakhir pekan mau bermain\nbulan lalu badai\nbulan depan musim kemarau\nminggu ini berawan\nkemarin saya sakit\nsekarang saya senang\nkatak kecil\nrubah lihat ayam\ntikus makan keripik\nsapi domba babi\nikan banyak\nini kamera bagus\njam buruk\nalpukat cokelat susu\njus jeruk tidak cukup dingin\nroti tebal\npermen stroberi\nhamburger besar cukup\nsaya mau bicara sekarang\nadik laki-laki tidak bisa bicara\nayah mau tidur lagi\nibu sedang makan alpukat\nkakek lihat burung hantu\nnenek minum susu panas\nsaya mau tas ransel\nkamu mau pensil rautan\nbuku tipis\npenggaris pensil kertas\nkoala sedang tidur\npanda besar lapar\nmalam bulan\nsiang matahari\npagi dingin\nsore berawan\nbadai besar kemarin\nseminggu hujan\nhari ini cukup panas\nsaya lihat kamu kemarin\nkamu tidak lihat saya\nadik laki-laki adik perempuan\nkakak laki-laki kakak perempuan\nayah ibu kakek\nsaya cinta kamu\nibu cinta ayah\nsaya tidak lapar lagi\nkamu haus lagi\nair putih cukup\nnasi sedikit\nkeripik banyak\nmakan malam hari ini\nmakan pagi besok\nsaya mau makan pagi\nanjing lapar mau makan\nkucing haus mau minum\nburung kecil\nayam bebek\nsumpit makan mie\ngarpu pisau\ncangkir panas\nini bukan kucing\nya ini anjing\ntidak saya tidak mau\nya saya mau\nsaya lihat bulan malam\ntv buruk\nhandphone tidak bagus\nsedang lihat laptop\nsaya sedang lihat laptop\nremot kontrol tv buruk\nac tidak dingin\nkipas angin kotor\nsaya sedang sedih\nkamu takut badai\nsaya tidak takut\nadik laki-laki bingung\nkakak perempuan marah\nnenek sakit lagi\nkakek mau tidur\ntelur goreng susu cokelat\nmakan hamburger kentang goreng\nminum jus jeruk dingin\nlihat kamera\nmenit lagi\nwaktu makan\nbabi makan nasi\ndomba kecil\nsapi besar\nbebek\nsaya dengar burung\nkamu tidak bicara\nakhir pekan\nbulan ini panas\nminggu lalu dingin"
#       }
#     ]
#   },
#   "finish_reason": "STOP",
#   "avg_logprobs": -0.3271040508033192
# }
# Response:
# {
#   "candidates": [
#     {
#       "content": {
#         "role": "model",
#         "parts": [
#           {
#             "text": "saya lapar mau makan nasi\nibu minum air putih dingin\nayah lihat tv malam ini\nkakak laki-laki bermain komputer lagi\nadik perempuan sedang tidur siang\nkucing kecil bermain di rumah (Correction: 'di' and 'rumah' are valid keywords. I will use them) -> kucing kecil bermain rumah\nrumah besar bersih\ntas ransel kotor buruk\nnenek sedih hari ini\nkakek senang lihat burung\nkamu haus mau minum susu\nadik laki-laki mau es krim cokelat\nkakak perempuan lihat handphone sekarang\nini bukan buku saya (Correction: 'saya' is a keyword. This is valid) -> ini bukan buku\nini rumah besar sekali (Correction: 'sekali' is not a keyword) -> ini rumah besar\nburung hantu tidak tidur pagi\nmonyet makan pisang di pohon (Correction: 'di' and 'pohon' are not keywords) -> monyet makan pisang\ngajah minum banyak air putih\nmusim kemarau sangat panas (Correction: 'sangat' is not a keyword) -> musim kemarau panas terik\nmusim hujan dingin berawan\nsaya sedang bingung sekarang\nkamu tidak sakit lagi\nsup ayam ini panas (Correction: 'ayam' and 'ini' are keywords, but 'sup ayam' is a compound. I'll stick to single keywords) -> sup panas\nes krim cokelat dingin\napel anggur pisang semangka\nmakan banyak buah-buahan\npiring mangkuk gelas bersih\nsendok garpu pisau tajam (Correction: 'tajam' is not a keyword) -> sendok garpu pisau\nsaya sedang makan mie ayam (Correction: 'mie ayam' is not a keyword) -> saya sedang makan mie\nayah minum susu cokelat panas\nibu mau makan sup ikan\nkelinci kecil takut anjing\nberuang besar sedang lapar\npenguin lihat banyak ikan\npenyu kura-kura berenang (Correction: 'berenang' is not a keyword) -> penyu kura-kura\nsaya mau pensil warna baru (Correction: 'baru' is not a keyword) -> saya mau pensil warna\nkertas origami tipis bagus\nmau gunting lem kertas\nkomputer laptop tablet bagus\nremot kontrol untuk tv (Correction: 'untuk' is not a keyword) -> remot kontrol tv\nkipas angin tidak dingin\nkulkas besar dingin bagus\nhalo terima kasih\nsampai jumpa besok pagi\nadik perempuan bermain origami\nkakak laki-laki dengar kamu\nsaya tidak dengar kamu bicara\nayam goreng kentang goreng enak (Correction: 'enak' is not a keyword) -> ayam goreng kentang goreng\nmakan nasi telur goreng tempe\nkamu jangan marah (Correction: 'jangan' is not a keyword) -> kamu marah\nsaya tidak sedang marah\nwaktu makan siang sekarang\nakhir pekan mau bermain\nbulan lalu hujan badai\nbulan depan musim kemarau\nminggu ini cuaca berawan (Correction: 'cuaca' is not a keyword) -> minggu ini berawan\nkemarin saya sakit kepala (Correction: 'kepala' is not a keyword) -> kemarin saya sakit\nsekarang saya senang lagi\nkatak kecil di kolam (Correction: 'di' and 'kolam' are not keywords) -> katak kecil\nrubah lihat ayam bebek\ntikus kecil makan keripik\nsapi domba babi\nikan berenang di air (Correction: 'berenang' and 'di' are not keywords) -> ikan di air putih (not logical) -> ikan banyak\nini kamera digital bagus (Correction: 'digital' is not a keyword) -> ini kamera bagus\njam tangan saya rusak (Correction: 'tangan' and 'rusak' are not keywords) -> jam buruk\nini jam buruk sekali (Correction: 'sekali' is not a keyword) -> ini jam buruk\nalpukat cokelat susu stroberi\njus jeruk tidak cukup dingin\nroti gandum tebal (Correction: 'gandum' is not a keyword) -> roti tebal\npermen stroberi cokelat\nhamburger besar dan enak (Correction: 'dan' and 'enak' are not keywords) -> hamburger besar\nsaya mau bicara dengan kamu (Correction: 'dengan' is not a keyword) -> saya mau bicara kamu\nadik laki-laki tidak bisa bicara\nayah mau tidur siang\nibu sedang makan buah alpukat\nkakek lihat burung hantu\nnenek minum susu hangat (Correction: 'hangat' is not a keyword) -> nenek minum susu\nsaya mau tas ransel itu (Correction: 'itu' is not a keyword) -> saya mau tas ransel\nkamu mau pensil rautan\nbuku tulis tipis (Correction: 'tulis' is not a keyword) -> buku tipis\npenggaris pensil kertas lem\nkoala tidur di atas pohon (Correction: 'di' 'atas' 'pohon' are not keywo ...
#           },
#           {
#             "text": "saya lapar mau makan nasi\nibu minum air putih dingin\nayah lihat tv malam\nkakak laki-laki bermain komputer\nadik perempuan sedang tidur\nkucing kecil bermain lagi\nanjing besar makan roti\nhari ini matahari terik\nbesok pagi hujan\nbuku ini tebal bagus\ntas ransel kotor buruk\nnenek sedih hari ini\nkakek senang lihat burung\nsaya mau makan ayam goreng\nkamu haus mau minum susu\nadik laki-laki mau es krim\nkakak perempuan lihat handphone\nini bukan buku kamu\nrumah besar bersih\nburung hantu tidak tidur\nmonyet makan pisang\ngajah minum banyak air putih\nmusim kemarau panas\nmusim hujan dingin\nsaya sedang bingung\nkamu tidak sakit\nsup panas\nes krim cokelat dingin\napel anggur semangka pisang\nmakan banyak buah-buahan\npiring mangkuk gelas bersih\nsendok garpu pisau\nsaya sedang makan mie\nayah minum susu cokelat\nibu mau makan sup\nkelinci kecil takut\nberuang besar lapar\npenguin lihat ikan\npenyu kura-kura\nsaya mau pensil warna\nkertas origami tipis\nmau gunting lem\nkomputer laptop tablet\nremot kontrol ac\nkipas angin tidak dingin\nkulkas besar bagus\ntoilet kotor\nhalo terima kasih\nsampai jumpa besok\nadik perempuan bermain origami\nkakak laki-laki dengar kamu\nsaya tidak dengar kamu\nayam goreng kentang goreng\nmakan nasi telur goreng\nkamu marah lagi\nsaya tidak sedang marah\nwaktu makan siang\nakhir pekan mau bermain\nbulan lalu badai\nbulan depan musim kemarau\nminggu ini berawan\nkemarin saya sakit\nsekarang saya senang\nkatak kecil\nrubah lihat ayam\ntikus makan keripik\nsapi domba babi\nikan banyak\nini kamera bagus\njam buruk\nalpukat cokelat susu\njus jeruk tidak cukup dingin\nroti tebal\npermen stroberi\nhamburger besar cukup\nsaya mau bicara sekarang\nadik laki-laki tidak bisa bicara\nayah mau tidur lagi\nibu sedang makan alpukat\nkakek lihat burung hantu\nnenek minum susu panas\nsaya mau tas ransel\nkamu mau pensil rautan\nbuku tipis\npenggaris pensil kertas\nkoala sedang tidur\npanda besar lapar\nmalam bulan\nsiang matahari\npagi dingin\nsore berawan\nbadai besar kemarin\nseminggu hujan\nhari ini cukup panas\nsaya lihat kamu kemarin\nkamu tidak lihat saya\nadik laki-laki adik perempuan\nkakak laki-laki kakak perempuan\nayah ibu kakek\nsaya cinta kamu\nibu cinta ayah\nsaya tidak lapar lagi\nkamu haus lagi\nair putih cukup\nnasi sedikit\nkeripik banyak\nmakan malam hari ini\nmakan pagi besok\nsaya mau makan pagi\nanjing lapar mau makan\nkucing haus mau minum\nburung kecil\nayam bebek\nsumpit makan mie\ngarpu pisau\ncangkir panas\nini bukan kucing\nya ini anjing\ntidak saya tidak mau\nya saya mau\nsaya lihat bulan malam\ntv buruk\nhandphone tidak bagus\nsedang lihat laptop\nsaya sedang lihat laptop\nremot kontrol tv buruk\nac tidak dingin\nkipas angin kotor\nsaya sedang sedih\nkamu takut badai\nsaya tidak takut\nadik laki-laki bingung\nkakak perempuan marah\nnenek sakit lagi\nkakek mau tidur\ntelur goreng susu cokelat\nmakan hamburger kentang goreng\nminum jus jeruk dingin\nlihat kamera\nmenit lagi\nwaktu makan\nbabi makan nasi\ndomba kecil\nsapi besar\nbebek\nsaya dengar burung\nkamu tidak bicara\nakhir pekan\nbulan ini panas\nminggu lalu dingin"
#           }
#         ]
#       },
#       "finish_reason": "STOP",
#       "avg_logprobs": -0.3271040508033192
#     }
#   ],
#   "usage_metadata": {
#     "prompt_token_count": 755,
#     "candidates_token_count": 4425,
#     "total_token_count": 10602,
#     "prompt_tokens_details": [
#       {
#         "modality": "TEXT",
#         "token_count": 755
#       }
#     ],
#     "candidates_tokens_details": [
#       {
#         "modality": "TEXT",
#         "token_count": 4425
#       }
#     ],
#     "thoughts_token_count": 5422
#   },
#   "model_version": "gemini-2.5-pro",
#   "create_time": "2025-09-26T06:16:35.098391Z",
#   "response_id": "wy_WaNeABrCemecPjd2xqAg"
# }. Retrying in 10s...
# 2025-09-26 06:19:18 - INFO - Success. Added 38 new valid phrases. New total: 4395
# 2025-09-26 06:19:18 - INFO - Checkpoint saved with 4395 records.
# 2025-09-26 06:19:19 - INFO - Requesting 150 new phrases. (Current unique total: 4395/5000)
# 2025-09-26 06:20:03 - INFO - Success. Added 15 new valid phrases. New total: 4410
# 2025-09-26 06:20:03 - INFO - Checkpoint saved with 4410 records.
# 2025-09-26 06:20:03 - INFO - Requesting 150 new phrases. (Current unique total: 4410/5000)
# 2025-09-26 06:20:04 - ERROR - Attempt 1/5: An API error occurred: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.. Retrying in 10s...
# 2025-09-26 06:21:21 - INFO - Success. Added 21 new valid phrases. New total: 4431
# 2025-09-26 06:21:21 - INFO - Checkpoint saved with 4431 records.
# 2025-09-26 06:21:22 - INFO - Requesting 150 new phrases. (Current unique total: 4431/5000)
# 2025-09-26 06:22:14 - INFO - Success. Added 23 new valid phrases. New total: 4454
# 2025-09-26 06:22:14 - INFO - Checkpoint saved with 4454 records.
# 2025-09-26 06:22:15 - INFO - Requesting 150 new phrases. (Current unique total: 4454/5000)
# 2025-09-26 06:23:13 - INFO - Success. Added 16 new valid phrases. New total: 4470
# 2025-09-26 06:23:13 - INFO - Checkpoint saved with 4470 records.
# 2025-09-26 06:23:13 - INFO - Requesting 150 new phrases. (Current unique total: 4470/5000)
# 2025-09-26 06:24:06 - INFO - Success. Added 31 new valid phrases. New total: 4501
# 2025-09-26 06:24:06 - INFO - Checkpoint saved with 4501 records.
# 2025-09-26 06:24:07 - INFO - Requesting 150 new phrases. (Current unique total: 4501/5000)
# 2025-09-26 06:25:15 - INFO - Success. Added 36 new valid phrases. New total: 4537
# 2025-09-26 06:25:15 - INFO - Checkpoint saved with 4537 records.
# 2025-09-26 06:25:16 - INFO - Requesting 150 new phrases. (Current unique total: 4537/5000)
# 2025-09-26 06:26:16 - INFO - Success. Added 40 new valid phrases. New total: 4577
# 2025-09-26 06:26:16 - INFO - Checkpoint saved with 4577 records.
# 2025-09-26 06:26:17 - INFO - Requesting 150 new phrases. (Current unique total: 4577/5000)
# 2025-09-26 06:27:08 - INFO - Success. Added 30 new valid phrases. New total: 4607
# 2025-09-26 06:27:08 - INFO - Checkpoint saved with 4607 records.
# 2025-09-26 06:27:08 - INFO - Requesting 150 new phrases. (Current unique total: 4607/5000)
# 2025-09-26 06:27:18 - ERROR - Attempt 1/5: An API error occurred: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.. Retrying in 10s...
# 2025-09-26 06:28:12 - INFO - Success. Added 20 new valid phrases. New total: 4627
# 2025-09-26 06:28:12 - INFO - Checkpoint saved with 4627 records.
# 2025-09-26 06:28:12 - INFO - Requesting 150 new phrases. (Current unique total: 4627/5000)
# 2025-09-26 06:28:17 - ERROR - Attempt 1/5: An API error occurred: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.. Retrying in 10s...
# 2025-09-26 06:29:35 - INFO - Success. Added 25 new valid phrases. New total: 4652
# 2025-09-26 06:29:35 - INFO - Checkpoint saved with 4652 records.
# 2025-09-26 06:29:35 - INFO - Requesting 150 new phrases. (Current unique total: 4652/5000)
# 2025-09-26 06:30:42 - INFO - Success. Added 30 new valid phrases. New total: 4682
# 2025-09-26 06:30:42 - INFO - Checkpoint saved with 4682 records.
# 2025-09-26 06:30:42 - INFO - Requesting 150 new phrases. (Current unique total: 4682/5000)
# 2025-09-26 06:31:54 - INFO - Success. Added 14 new valid phrases. New total: 4696
# 2025-09-26 06:31:54 - INFO - Checkpoint saved with 4696 records.
# 2025-09-26 06:31:55 - INFO - Requesting 150 new phrases. (Current unique total: 4696/5000)
# 2025-09-26 06:33:02 - INFO - Success. Added 20 new valid phrases. New total: 4716
# 2025-09-26 06:33:02 - INFO - Checkpoint saved with 4716 records.
# 2025-09-26 06:33:02 - INFO - Requesting 150 new phrases. (Current unique total: 4716/5000)
# 2025-09-26 06:33:47 - INFO - Success. Added 24 new valid phrases. New total: 4740
# 2025-09-26 06:33:47 - INFO - Checkpoint saved with 4740 records.
# 2025-09-26 06:33:47 - INFO - Requesting 150 new phrases. (Current unique total: 4740/5000)
# 2025-09-26 06:34:19 - INFO - Success. Added 20 new valid phrases. New total: 4760
# 2025-09-26 06:34:19 - INFO - Checkpoint saved with 4760 records.
# 2025-09-26 06:34:19 - INFO - Requesting 150 new phrases. (Current unique total: 4760/5000)
# 2025-09-26 06:35:00 - WARNING - Attempt 1/5: Batch yielded 0 new valid phrases. Retrying...
# 2025-09-26 06:36:13 - INFO - Success. Added 24 new valid phrases. New total: 4784
# 2025-09-26 06:36:13 - INFO - Checkpoint saved with 4784 records.
# 2025-09-26 06:36:14 - INFO - Requesting 150 new phrases. (Current unique total: 4784/5000)
# 2025-09-26 06:37:06 - INFO - Success. Added 23 new valid phrases. New total: 4807
# 2025-09-26 06:37:06 - INFO - Checkpoint saved with 4807 records.
# 2025-09-26 06:37:06 - INFO - Requesting 150 new phrases. (Current unique total: 4807/5000)
# 2025-09-26 06:38:06 - INFO - Success. Added 44 new valid phrases. New total: 4851
# 2025-09-26 06:38:06 - INFO - Checkpoint saved with 4851 records.
# 2025-09-26 06:38:06 - INFO - Requesting 149 new phrases. (Current unique total: 4851/5000)
# 2025-09-26 06:38:48 - INFO - Success. Added 11 new valid phrases. New total: 4862
# 2025-09-26 06:38:48 - INFO - Checkpoint saved with 4862 records.
# 2025-09-26 06:38:49 - INFO - Requesting 138 new phrases. (Current unique total: 4862/5000)
# 2025-09-26 06:39:52 - INFO - Success. Added 14 new valid phrases. New total: 4876
# 2025-09-26 06:39:52 - INFO - Checkpoint saved with 4876 records.
# 2025-09-26 06:39:52 - INFO - Requesting 124 new phrases. (Current unique total: 4876/5000)
# 2025-09-26 06:40:59 - INFO - Success. Added 20 new valid phrases. New total: 4896
# 2025-09-26 06:40:59 - INFO - Checkpoint saved with 4896 records.
# 2025-09-26 06:40:59 - INFO - Requesting 104 new phrases. (Current unique total: 4896/5000)
# 2025-09-26 06:41:48 - INFO - Success. Added 30 new valid phrases. New total: 4926
# 2025-09-26 06:41:48 - INFO - Checkpoint saved with 4926 records.
# 2025-09-26 06:41:48 - INFO - Requesting 74 new phrases. (Current unique total: 4926/5000)
# 2025-09-26 06:42:30 - INFO - Success. Added 4 new valid phrases. New total: 4930
# 2025-09-26 06:42:30 - INFO - Checkpoint saved with 4930 records.
# 2025-09-26 06:42:31 - INFO - Requesting 70 new phrases. (Current unique total: 4930/5000)
# 2025-09-26 06:43:04 - INFO - Success. Added 11 new valid phrases. New total: 4941
# 2025-09-26 06:43:04 - INFO - Checkpoint saved with 4941 records.
# 2025-09-26 06:43:05 - INFO - Requesting 59 new phrases. (Current unique total: 4941/5000)
# 2025-09-26 06:43:37 - INFO - Success. Added 9 new valid phrases. New total: 4950
# 2025-09-26 06:43:37 - INFO - Checkpoint saved with 4950 records.
# 2025-09-26 06:43:38 - INFO - Requesting 50 new phrases. (Current unique total: 4950/5000)
# 2025-09-26 06:44:09 - INFO - Success. Added 5 new valid phrases. New total: 4955
# 2025-09-26 06:44:09 - INFO - Checkpoint saved with 4955 records.
# 2025-09-26 06:44:09 - INFO - Requesting 45 new phrases. (Current unique total: 4955/5000)
# 2025-09-26 06:44:42 - INFO - Success. Added 10 new valid phrases. New total: 4965
# 2025-09-26 06:44:42 - INFO - Checkpoint saved with 4965 records.
# 2025-09-26 06:44:43 - INFO - Requesting 35 new phrases. (Current unique total: 4965/5000)
# 2025-09-26 06:44:45 - ERROR - Attempt 1/5: An API error occurred: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.. Retrying in 10s...
# 2025-09-26 06:45:25 - INFO - Success. Added 5 new valid phrases. New total: 4970
# 2025-09-26 06:45:25 - INFO - Checkpoint saved with 4970 records.
# 2025-09-26 06:45:25 - INFO - Requesting 30 new phrases. (Current unique total: 4970/5000)
# 2025-09-26 06:45:50 - INFO - Success. Added 6 new valid phrases. New total: 4976
# 2025-09-26 06:45:50 - INFO - Checkpoint saved with 4976 records.
# 2025-09-26 06:45:50 - INFO - Requesting 24 new phrases. (Current unique total: 4976/5000)
# 2025-09-26 06:46:11 - INFO - Success. Added 3 new valid phrases. New total: 4979
# 2025-09-26 06:46:11 - INFO - Checkpoint saved with 4979 records.
# 2025-09-26 06:46:12 - INFO - Requesting 21 new phrases. (Current unique total: 4979/5000)
# 2025-09-26 06:46:26 - ERROR - Attempt 1/5: An API error occurred: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.. Retrying in 10s...
# 2025-09-26 06:46:54 - INFO - Success. Added 3 new valid phrases. New total: 4982
# 2025-09-26 06:46:54 - INFO - Checkpoint saved with 4982 records.
# 2025-09-26 06:46:55 - INFO - Requesting 18 new phrases. (Current unique total: 4982/5000)
# 2025-09-26 06:47:12 - INFO - Success. Added 2 new valid phrases. New total: 4984
# 2025-09-26 06:47:12 - INFO - Checkpoint saved with 4984 records.
# 2025-09-26 06:47:13 - INFO - Requesting 16 new phrases. (Current unique total: 4984/5000)
# 2025-09-26 06:47:34 - INFO - Success. Added 2 new valid phrases. New total: 4986
# 2025-09-26 06:47:34 - INFO - Checkpoint saved with 4986 records.
# 2025-09-26 06:47:35 - INFO - Requesting 14 new phrases. (Current unique total: 4986/5000)
# 2025-09-26 06:47:50 - WARNING - Attempt 1/5: Batch yielded 0 new valid phrases. Retrying...
# 2025-09-26 06:48:22 - INFO - Success. Added 1 new valid phrases. New total: 4987
# 2025-09-26 06:48:22 - INFO - Checkpoint saved with 4987 records.
# 2025-09-26 06:48:23 - INFO - Requesting 13 new phrases. (Current unique total: 4987/5000)
# 2025-09-26 06:48:38 - INFO - Success. Added 1 new valid phrases. New total: 4988
# 2025-09-26 06:48:38 - INFO - Checkpoint saved with 4988 records.
# 2025-09-26 06:48:38 - INFO - Requesting 12 new phrases. (Current unique total: 4988/5000)
# 2025-09-26 06:48:51 - WARNING - Attempt 1/5: Batch yielded 0 new valid phrases. Retrying...
# 2025-09-26 06:49:18 - INFO - Success. Added 1 new valid phrases. New total: 4989
# 2025-09-26 06:49:18 - INFO - Checkpoint saved with 4989 records.
# 2025-09-26 06:49:18 - INFO - Requesting 11 new phrases. (Current unique total: 4989/5000)
# 2025-09-26 06:49:32 - INFO - Success. Added 4 new valid phrases. New total: 4993
# 2025-09-26 06:49:32 - INFO - Checkpoint saved with 4993 records.
# 2025-09-26 06:49:32 - INFO - Requesting 7 new phrases. (Current unique total: 4993/5000)
# 2025-09-26 06:49:47 - INFO - Success. Added 2 new valid phrases. New total: 4995
# 2025-09-26 06:49:47 - INFO - Checkpoint saved with 4995 records.
# 2025-09-26 06:49:48 - INFO - Requesting 5 new phrases. (Current unique total: 4995/5000)
# 2025-09-26 06:50:02 - INFO - Success. Added 2 new valid phrases. New total: 4997
# 2025-09-26 06:50:02 - INFO - Checkpoint saved with 4997 records.
# 2025-09-26 06:50:03 - INFO - Requesting 3 new phrases. (Current unique total: 4997/5000)
# 2025-09-26 06:50:12 - ERROR - Attempt 1/5: An API error occurred: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.. Retrying in 10s...
# 2025-09-26 06:50:30 - ERROR - Attempt 2/5: An API error occurred: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.. Retrying in 10s...
# 2025-09-26 06:50:50 - INFO - Success. Added 1 new valid phrases. New total: 4998
# 2025-09-26 06:50:50 - INFO - Checkpoint saved with 4998 records.
# 2025-09-26 06:50:51 - INFO - Requesting 2 new phrases. (Current unique total: 4998/5000)
# 2025-09-26 06:51:00 - INFO - Success. Added 1 new valid phrases. New total: 4999
# 2025-09-26 06:51:00 - INFO - Checkpoint saved with 4999 records.
# 2025-09-26 06:51:00 - INFO - Requesting 1 new phrases. (Current unique total: 4999/5000)
# 2025-09-26 06:51:11 - ERROR - Attempt 1/5: An API error occurred: 429 Resource exhausted. Please try again later. Please refer to https://cloud.google.com/vertex-ai/generative-ai/docs/error-code-429 for more details.. Retrying in 10s...
# 2025-09-26 06:51:31 - WARNING - Attempt 2/5: Batch yielded 0 new valid phrases. Retrying...
# 2025-09-26 06:51:51 - INFO - Success. Added 1 new valid phrases. New total: 5000
# 2025-09-26 06:51:51 - INFO - Checkpoint saved with 5000 records.
# ---------------------------------------------------------
# 2025-09-26 06:51:51 - INFO - PROCESS COMPLETE!
# 2025-09-26 06:51:51 - INFO - Total UNIQUE data points created: 5000
# 2025-09-26 06:51:51 - INFO - Total time elapsed: 7553.93 seconds
# 2025-09-26 06:51:51 - INFO - Dataset successfully saved to 'Dataset_Key.txt'
# 2025-09-26 06:51:51 - INFO - Checkpoint file 'Dataset_Checkpoint.txt' removed.
